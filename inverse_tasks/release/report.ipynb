# %%
from ransac import *
from regularization import *
from iterative_regur import *

# %%
report_ransac(input_flag=0)
# Out:
# Expect number of iterations needed is 1100
# Number of iterations calculated: None
#
# RANSAC did not find the solution
# Result for 2 dispersion
# Do you want to repeat with higher dispersion?
# Y/N?
# Expect number of iterations needed is 1100
# Number of iterations calculated: None
#
# RANSAC did not find the solution
# Result for 3 dispersion
# Do you want to repeat with higher dispersion?
# Y/N?
# Expect number of iterations needed is 1100
# Number of iterations calculated: None
#
# RANSAC did not find the solution
# Result for 4 dispersion
# Do you want to repeat with higher dispersion?
# Y/N?
# Expect number of iterations needed is 1100
# Number of iterations calculated: None
#
# RANSAC did not find the solution
# Result for 6 dispersion
# Do you want to repeat with higher dispersion?
# Y/N?
# Expect number of iterations needed is 1100
# Number of iterations calculated: None
#
# RANSAC did not find the solution
# Result for 9 dispersion
# Do you want to repeat with higher dispersion?
# Y/N?
# Expect number of iterations needed is 1100
# Number of iterations calculated: 130
# Result found for 14 dispersion
# k sample: 0.7 k RANSAC: 0.726 k LsSqr: 0.642
# Calculation finish.

# %%
report_regularization()

# %%
iterative_solver(num_iterations=1e3, epsilon=1e-2, plot_default=False)

# %%
iterative_solver(num_iterations=1e3, epsilon=1e-3, plot_default=False)
