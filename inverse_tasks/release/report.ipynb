# %%
# from ransac import *
# from regularization import *
# from iterative_regur import *
# from derivation import *
# from density import *
# from rls import *
# from kalman import *
from fredholm import *

# %%
# report_ransac(input_flag=0)

# %%
# report_regularization()

# %%
# iterative_solver(num_iterations=1e3, epsilon=1e-2, plot_default=False)

# %%
# iterative_solver(num_iterations=1e3, epsilon=1e-3, plot_default=False)

# %% [markdown]
# Вариант 2
#
# Function 1: $f1(t) = \cos(200\pi t)^3 + \cos(10\pi t + pi/4)$
# Function 2: $f2(t) = t^2$
# Df1 = $-10 \pi \cdot(60 \cos^2(200 \pi t) \sin(200 \pi t) + \sin(\pi /4 + 10 \pi t))$
# Df2 = $2t$

# %%
# report_finite_diff(func_type=1, noisy_val=False, sigma=1e-2)
# report_finite_diff(func_type=1,  noisy_val=True, sigma=1e-3)
# report_finite_diff(func_type=1, noisy_val=True, sigma=1e-2)

# %%
# report_fourier(func_type=1, noisy_val=True, sigma=1)
# report_fourier(func_type=1, noisy_val=True, sigma=1e-2)

# %%
# report_finite_diff(func_type=2, noisy_val=False)
# report_finite_diff(func_type=2, noisy_val=True, sigma=1e-3)

# %%
# report_fourier(func_type=2, noisy_val=False, sigma=1e-2)
# report_fourier(func_type=2, noisy_val=True, sigma=1e-2)

# %%
# report_least_squares(sigma=1)
# report_least_squares(sigma=1e-1)
# report_least_squares(sigma=1e-2)

# %% [markdown]
# ### Task 8

# %% [markdown]
# $$\int_{-1}^1 P_n(x) P_m(x) dx = \dfrac{2}{2n+1} \delta_{n,m}$$
# $$f_n(x) = \sum^n_{l=0} a_l\, P_l(x)$$
# $$a_l = \dfrac{2l+1}{2} \int_{-1}^1 f(x) P_l(x) dx$$
# $$h(x) = 1,\,\,\,\lambda_n = \dfrac{2}{2n+1}$$

# %% [markdown]
# Так как пользуюсь полиномами Лежандра, всю выборку расположил между -1 и 1, нормируя на её максимум

# %%
# report_whole_data_density()
# report_slice_data_no_reg_dens()
# report_slice_data_with_reg_dens()

# %% [markdown]
# ### Task 9 (RLS)

# %%
# report_rls_diff_p(sigma=1e-1, h_len=15, p=15, l_loc=0.5, show_error=True, show_signal=False, show_result=True)
# report_rls_diff_l(sigma=1e-1, h_len=15, show_error=True, show_signal=False, show_result=True)

# %%
# report_memory_of_model(l_loc=1)
# report_memory_of_model(l_loc=0.95)

# %%
# report_audio()

# %% [markdown]
# ### Task 10 (Kalman)

# %%
# report_kalman(prob_outer=0.1)

# %%
# report_kalman(prob_outer=0.05)

# %%
# report_kalman(prob_outer=0.01)

# %% [markdown]
# ### Task Fredholm integral equation

# %%
report_fredholm(f, t)
